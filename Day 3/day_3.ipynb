# %%
print("Hello world")
# Out:
# Hello world

# %%
# Loading in a dataset
import seaborn as sns
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd

# %%
data = {
    "names": ["Dr Abc", "Mr BCD", "Ms DEF",]
}
df =pd.DataFrame(data)

# %%
df.head()
# Out:
#     names
# 0  Dr Abc
# 1  Mr BCD
# 2  Ms DEF

# %%
import re

# %%
df["cleanNames"] = df.names.apply(lambda x: re.sub(r"(Mr|Mrs|Dr|Ms)", "", x))
df
# Out:
#     names cleanNames
# 0  Dr Abc        Abc
# 1  Mr BCD        BCD
# 2  Ms DEF        DEF

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

df["embarked_1HC"] = encoder.fit_transform(df["embarked"])

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  embarked_1HC
# 0    man        True  NaN  Southampton    no  False             2
# 1  woman       False    C    Cherbourg   yes  False             0
# 2  woman       False  NaN  Southampton   yes   True             2
# 3  woman       False    C  Southampton   yes  False             2
# 4    man        True  NaN  Southampton    no   True             2

# %%
# Functions
def sayHello():
    print("Hello")

# %%
sayHello()
# Out:
# Hello

# %%
def sayHelloV2(name="Bob"):
    print("Hello", name)

# %%
sayHelloV2(name="Nirosh")
# Out:
# Hello Nirosh

# %%
sayHelloV2()
# Out:
# Hello Bob

# %%
def addition(a,b):
    '''
    This is the guidance or docs for this function. 

    a is an int
    b is an int

    the output will be an int
    '''
    answer = a+b
    return answer

# %%
addition()

# %%
X = addition(12,4)
print(X)
# Out:
# 16

# %% [markdown]
# Task:
# 1. Create a function that a takes a DF and return no duplicates or NAs (remove them).
# 2. Create a function that goes through every numerical col, removes outliers and outputs a CLEAN DF and an OUTLIER DF.
